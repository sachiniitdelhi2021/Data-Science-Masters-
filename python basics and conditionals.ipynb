# %%
print('this is my python program')
# Out:
# this is my python program

# %%
print 'my name is sachin'
# Out:
#   File "<ipython-input-2-284909d22adc>", line 1
#     print 'my name is sachin'
#                             ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print('my name is sachin')?

# %%
# my name is sachin  this is example of single line comment

# %%
'''sdggv
jxjx
nxxnj
xjjxxj
xnxx
mxjxjn
mxjnxjnx
jxj
xjnx
xxnjnx
xj'''
# this is an example of multi-line comment ,so we should use triple coat ''' in starting and at end also
# Out:
# 'sdggv\njxjx\nnxxnj\nxjjxxj\nxnxx\nmxjxjn\nmxjnxjnx\njxj\nxjnx\nxxnjnx\nxj'

# %%
'''print('sachin')
print('singh')
print('dangi')'''
# Out:
# "print('sachin')\nprint('singh')\nprint('dangi')"

# %%
a= 10
a
# Out:
# 10

# %%
type(a)
# Out:
# int

# %%
b= 'sachin'

# %%
b
# Out:
# 'sachin'

# %%
type(b)
# Out:
# str

# %%
print(a,b)
# Out:
# 10 sachin

# %%
print(a,b,'dangi')
# Out:
# 10 sachin dangi

# %%
a=20
b=30

# %%
a,b,c=20,30,'dangi'

# %%
a
# Out:
# 20

# %%
b
# Out:
# 30

# %%
c
# Out:
# 'dangi'

# %%
type(a)
# Out:
# int

# %%
type(c)
# Out:
# str

# %%
a,b,c
# Out:
# (20, 30, 'dangi')

# %%
a@= 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-8da46fb44093> in <module>()
# ----> 1 a@= 10
#
# TypeError: unsupported operand type(s) for @=: 'int' and 'int'

# %%
1b=20
# Out:
#   File "<ipython-input-42-65b1a61ce9ea>", line 1
#     1b=20
#      ^
# SyntaxError: invalid syntax

# %%
b1=30

# %%
_b=100

# %%
a=1.7765433456

# %%
type(a)
# Out:
# float

# %%
b=True
c=False

# %%
type(b)
# Out:
# bool

# %%
print(True+True+True+False+True)
print(False-True+True)
# Out:
# 4
# 0

# %%
True/False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-55-f64d1295bbce> in <module>()
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %%
n= 40+4j

# %%
type(n)
# Out:
# complex

# %%
n
# Out:
# (40+4j)

# %%
n.rea()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-748e4825d496> in <module>()
# ----> 1 n.rea()
#
# AttributeError: 'complex' object has no attribute 'rea'

# %%
n.real()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-60b203abdf77> in <module>()
# ----> 1 n.real()
#
# TypeError: 'float' object is not callable

# %%
n.real
# Out:
# 40.0

# %%
n.imag
# Out:
# 4.0

# %%
1+'sachin'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-8c2d613e7573> in <module>()
# ----> 1 1+'sachin'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
str(1)+'sachin'
# Out:
# '1sachin'

# %%
'1'+'sachin'
# Out:
# '1sachin'

# %%
'sachin'+'sachin'
# Out:
# 'sachinsachin'

# %%
'sachin'*2
# Out:
# 'sachinsachin'

# %%
a=input()
# Out:
# 10

# %%
a
# Out:
# '10'

# %%
a=int(input())
b=int(input())
c=int(input())
# Out:
# 10
# 10
# 10

# %%
d=(a+b)/c
d
n=10+10j
d1=d+n
d1
str(d1)+'sachin'
# Out:
# '(12+10j)sachin'

# %%
a=int(input('input a no less than 34'))
# Out:
# input a no less than 3456

# %%
a=int(input('input a number'))
if a<34:
  print('data input is lesser than 34 and i m fine with it')

elif a<100:
  print('input is less then 100')

else:
  print('user input is not lesser then 34')
# Out:
# input a number12
# data input is lesser than 34 and i m fine with it

# %%
salary=int(input('what is ur salary'))
if salary>1000:
  print('u can buy a car')
  if salary>5000:
    print('u can buy nano')
    if salary>10000:
      print('u can buy honda' )   # all if are inside nested loop and if last 'if' is true loop will not terminate and all elif and else will not execute 
    if True:
      print('false code')
elif salary>500 and salary<1000:
  print('u can buy a bike')
elif salary>100:
  print('u can buy cycle')
else:
  print('u should save ')
# Out:
# what is ur salary100001
# u can buy a car
# u can buy nano
# u can buy honda
# false code
