# %%
import pandas as pd   # importing pandas for doing all possible operations with data like data manipulation, data pre-procrssing
# pd.read_csv('mydata.csv')      # 'read' function for reading data of any file format -csv,excel,txt etc

# %%
df=pd.read_csv('D:\sample100.csv')   # here we are giving path of file with file name

# %%
#  we can dump all of data after reading inside a variable also for further operations like
df
# Out:
#     Serial Number                   Company Name  Employee Markme  \
# 0   9788189999599                 TALES OF SHIVA             Mark
# 1   9780099578079      1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2   9780198082897                       MY KUMAN             Mark
# 3   9780007880331        THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4   9780545060455               THE BLACK CIRCLE             Mark
# ..            ...                            ...              ...
# 94  9788184821536  MORE STORIES FROM THE JATAKAS             Mark
# 95  9788184821543           MORE TALES OF BIRBAL                -
# 96  9788184821550         TALES FROM THE JATAKAS                -
# 97  9788184821567               RAMarkS OF MEWAR                -
# 98  9788184821574       THE SONS OF THE PANDAVAS                -
#
#            Description  Leave
# 0                 mark      0
# 1                 Mark      0
# 2                 Mark      0
# 3   4TH HARPER COLLINS      2
# ...

# %%
df1=df.head()  # using variable 'df' inside which we stored all data of file and head function of pandas we can get top 5 rows data if no argument is given

# %%
df1
# Out:
#    Serial Number               Company Name  Employee Markme  \
# 0  9788189999599             TALES OF SHIVA             Mark
# 1  9780099578079  1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2  9780198082897                   MY KUMAN             Mark
# 3  9780007880331    THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4  9780545060455           THE BLACK CIRCLE             Mark
#
#           Description  Leave
# 0                mark      0
# 1                Mark      0
# 2                Mark      0
# 3  4TH HARPER COLLINS      2
# 4  4TH HARPER COLLINS      0

# %%
df.head(10)   # data of first 10 rows
# Out:
#    Serial Number                         Company Name  Employee Markme  \
# 0  9788189999599                       TALES OF SHIVA             Mark
# 1  9780099578079            1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2  9780198082897                             MY KUMAN             Mark
# 3  9780007880331              THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4  9780545060455                     THE BLACK CIRCLE             Mark
# 5  9788126525072        THE THREE LAWS OF PERFORMANCE             Mark
# 6  9789381626610                    CHAMarkKYA MANTRA             Mark
# 7  9788184513523                             59.FLAGS             Mark
# 8  9780743234801  THE POWER OF POSITIVE THINKING FROM             Mark
# 9  9789381529621           YOU CAN IF YO THINK YO CAN            PEALE
#
#           Description  Leave
# 0                mark      0
# 1                Mark      0
# 2                Mark      0
# 3  4TH HARPER COLLINS      2
# 4  4TH HARPER COLLINS      0
# ...

# %%
df.tail()   # same as head function but from bottom of file
# Out:
#     Serial Number                   Company Name Employee Markme Description  \
# 94  9788184821536  MORE STORIES FROM THE JATAKAS            Mark         ACK
# 95  9788184821543           MORE TALES OF BIRBAL               -         ACK
# 96  9788184821550         TALES FROM THE JATAKAS               -         ACK
# 97  9788184821567               RAMarkS OF MEWAR               -         ACK
# 98  9788184821574       THE SONS OF THE PANDAVAS               -         ACK
#
#     Leave
# 94      0
# 95      0
# 96      0
# 97      0
# 98      0

# %%
df.tail(10)   # bottom 10 rows data
# Out:
#     Serial Number                     Company Name Employee Markme  \
# 89  9788184820997  MORE TALES FROM THE PANCHTANTRA     AMarkNT PAL
# 90  9788184824018       THE GREAT MUGHALS {5-IN-1}        AMarkNT.
# 91  9788184824049                FAMOUS SCIENTISTS            Mark
# 92  9788184825978                         KOMarkRK            Mark
# 93  9788184826098                 THE MUGHAL COURT         REEMark
# 94  9788184821536    MORE STORIES FROM THE JATAKAS            Mark
# 95  9788184821543             MORE TALES OF BIRBAL               -
# 96  9788184821550           TALES FROM THE JATAKAS               -
# 97  9788184821567                 RAMarkS OF MEWAR               -
# 98  9788184821574         THE SONS OF THE PANDAVAS               -
#
#    Description  Leave
# 89         ACK      0
# 90         ACK      0
# 91         ACK      0
# 92         ACK      0
# 93         ACK      0
# 94         ACK      0
# 95         ACK      0
# 96         ACK      0
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#  dataframe is a kind of tabular form of storing a data

# %%
# we can convert data stored inside any variable into a new csv format file like 
df1.to_csv('sample100_top5rows.csv')

# %%
pd.read_csv('sample100_top5rows.csv')  # again reading data from csv file
# Out:
#    Unnamed: 0  Serial Number               Company Name  Employee Markme  \
# 0           0  9788189999599             TALES OF SHIVA             Mark
# 1           1  9780099578079  1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2           2  9780198082897                   MY KUMAN             Mark
# 3           3  9780007880331    THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4           4  9780545060455           THE BLACK CIRCLE             Mark
#
#           Description  Leave
# 0                mark      0
# 1                Mark      0
# 2                Mark      0
# 3  4TH HARPER COLLINS      2
# 4  4TH HARPER COLLINS      0

# %%
#  we can make these headers to be inside table using header=none like 
pd.read_csv('sample100_top5rows.csv',header=None)
# Out:
#      0              1                          2                3  \
# 0  NaN  Serial Number               Company Name  Employee Markme
# 1  0.0  9788189999599             TALES OF SHIVA             Mark
# 2  1.0  9780099578079  1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 3  2.0  9780198082897                   MY KUMAN             Mark
# 4  3.0  9780007880331    THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 5  4.0  9780545060455           THE BLACK CIRCLE             Mark
#
#                     4      5
# 0         Description  Leave
# 1                mark      0
# 2                Mark      0
# 3                Mark      0
# 4  4TH HARPER COLLINS      2
# 5  4TH HARPER COLLINS      0

# %%
#  i can also give my own column names , by replacing already existing column names like
pd.read_csv('sample100_top5rows.csv',names=['a','b','c','d','e'])
# Out:
#                  a                          b                c  \
# NaN  Serial Number               Company Name  Employee Markme
# 0.0  9788189999599             TALES OF SHIVA             Mark
# 1.0  9780099578079  1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2.0  9780198082897                   MY KUMAN             Mark
# 3.0  9780007880331    THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4.0  9780545060455           THE BLACK CIRCLE             Mark
#
#                       d      e
# NaN         Description  Leave
# 0.0                mark      0
# 1.0                Mark      0
# 2.0                Mark      0
# 3.0  4TH HARPER COLLINS      2
# 4.0  4TH HARPER COLLINS      0

# %%
# we can also skeep any row which i don't want using 'skiprows=[]' inside pd.read like 
pd.read_csv('sample100_top5rows.csv',skiprows=[0,1,2])
# Out:
#    2  9780198082897                 MY KUMAN           Mark  \
# 0  3  9780007880331  THE GOD OF SMAAL THINGS  ARUNDHATI ROY
# 1  4  9780545060455         THE BLACK CIRCLE           Mark
#
#                Mark.1  0
# 0  4TH HARPER COLLINS  2
# 1  4TH HARPER COLLINS  0

# %%
# if i want to consider any value as NA value i can do this like 
pd.read_csv('sample100_top5rows.csv',na_values=[1])
# Out:
#    Unnamed: 0  Serial Number               Company Name  Employee Markme  \
# 0         0.0  9788189999599             TALES OF SHIVA             Mark
# 1         NaN  9780099578079  1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2         2.0  9780198082897                   MY KUMAN             Mark
# 3         3.0  9780007880331    THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4         4.0  9780545060455           THE BLACK CIRCLE             Mark
#
#           Description  Leave
# 0                mark      0
# 1                Mark      0
# 2                Mark      0
# 3  4TH HARPER COLLINS      2
# 4  4TH HARPER COLLINS      0

# %%
# in this case the company name 'tales of shiva' will be replaced by NAN like   
pd.read_csv('sample100_top5rows.csv',na_values=['TALES OF SHIVA'])
# Out:
#    Unnamed: 0  Serial Number               Company Name  Employee Markme  \
# 0           0  9788189999599                        NaN             Mark
# 1           1  9780099578079  1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2           2  9780198082897                   MY KUMAN             Mark
# 3           3  9780007880331    THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4           4  9780545060455           THE BLACK CIRCLE             Mark
#
#           Description  Leave
# 0                mark      0
# 1                Mark      0
# 2                Mark      0
# 3  4TH HARPER COLLINS      2
# 4  4TH HARPER COLLINS      0

# %%
df.describe()  # 'describe'is another function in pandas which gives various details about  data like below
# Out:
#        Serial Number      Leave
# count   9.900000e+01  99.000000
# mean    9.687307e+12   0.818182
# std     9.827211e+11   2.158815
# min     8.187776e+09   0.000000
# 25%     9.781743e+12   0.000000
# 50%     9.788185e+12   0.000000
# 75%     9.789382e+12   0.500000
# max     9.789386e+12  10.000000

# %%
df2=pd.read_csv('mydata.csv')

# %%
df2
# Out:
#      x1        x2          x3
# 0  1234     dangi  2022-05-19
# 1  1234     dangi  2022-05-19
# 2  1234     dangi  2022-05-20
# 3  1234     dangi  2022-05-20
# 4  5678    thakur  2022-05-20
# 5  9876    rajput  2022-05-20
# 6   987     singh  2022-05-20
# 7  6554     hindu  2022-05-20
# 8  1919  shatreya  2022-05-20
# 9   101     hindu  2022-05-20

# %%
df2.dtypes()        # this gives datatypes of each columns
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [37], in <cell line: 1>()
# ----> 1 df2.dtypes()
#
# TypeError: 'Series' object is not callable

# %%
# if we don't want to store the index of each row  at the time of storing a data in file of any format 
#  if any format file say here is csv format file is having unnecessary index in column before main data column then to remove those and than storing file wecan use
df.to_csv('sample100.csv',index=False)

# %%
# if i don't want to store data in file with headers so for saving data in csv format file without headers i can use 
#  no un wanted row index and saving my data with separater as '*'  
df.to_csv('sample100.csv',index=False,header=False,sep='*')

# %%
# for knowing what are the column names and getting these inside list
df.columns
# Out:
# Index(['Serial Number', 'Company Name', 'Employee Markme', 'Description',
#        'Leave'],
#       dtype='object')

# %%
# can get info about any single column also like
df['Company Name']
# Out:
# 0                    TALES OF SHIVA
# 1         1Q84 THE COMPLETE TRILOGY
# 2                          MY KUMAN
# 3           THE GOD OF SMAAL THINGS
# 4                  THE BLACK CIRCLE
#                   ...
# 94    MORE STORIES FROM THE JATAKAS
# 95             MORE TALES OF BIRBAL
# 96           TALES FROM THE JATAKAS
# 97                 RAMarkS OF MEWAR
# 98         THE SONS OF THE PANDAVAS
# Name: Company Name, Length: 99, dtype: object

# %%
type(df['Company Name'])  # our complete file data stored inside a variable df was in form of dataframe but individual column is in series format
# Out:
# pandas.core.series.Series

# %%
# if i want column data also in dataframe format than give column name inside a list like
df[['Company Name']]
# Out:
#                      Company Name
# 0                  TALES OF SHIVA
# 1       1Q84 THE COMPLETE TRILOGY
# 2                        MY KUMAN
# 3         THE GOD OF SMAAL THINGS
# 4                THE BLACK CIRCLE
# ..                            ...
# 94  MORE STORIES FROM THE JATAKAS
# 95           MORE TALES OF BIRBAL
# 96         TALES FROM THE JATAKAS
# 97               RAMarkS OF MEWAR
# 98       THE SONS OF THE PANDAVAS
#
# [99 rows x 1 columns]

# %%
#  now if i check type of this it will be dataframe
type(df[['Company Name']] )
# Out:
# pandas.core.frame.DataFrame

# %%
df[['Company Name','Employee Markme']]
# Out:
#                      Company Name  Employee Markme
# 0                  TALES OF SHIVA             Mark
# 1       1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2                        MY KUMAN             Mark
# 3         THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4                THE BLACK CIRCLE             Mark
# ..                            ...              ...
# 94  MORE STORIES FROM THE JATAKAS             Mark
# 95           MORE TALES OF BIRBAL                -
# 96         TALES FROM THE JATAKAS                -
# 97               RAMarkS OF MEWAR                -
# 98       THE SONS OF THE PANDAVAS                -
#
# [99 rows x 2 columns]

# %%
# for reading a data from excel sheet 
df4=pd.read_excel('D:\Practice data_1.xlsx')   # this will read data of first sheet only
# Out:
#    Hardcopy    Status                                         LC Name  \
# 0        No  Inactive  FRAMEBOXX ANIMATION AND VISUAL EFFECTS PVT LTD
# 1        No  Inactive                                            IICM
# 2        No  Inactive                                            IICM
# 3        No  Inactive                                            IIHT
# 4       Yes    Active                            INDIAN HOTEL ACADEMY
# ..      ...       ...                                             ...
# 94      Yes    Active                                       IT CAMPUS
# 95       No  Inactive           MAURYA'S INSTITUTE OF FOOD TECHNOLOGY
# 96      Yes    Active                             TALENT STUDY CIRCLE
# 97      Yes    Active                             TALENT STUDY CIRCLE
# 98      Yes    Active                                  VEER COMPUTERS
#
#           State Streams  offered
# 0         Delhi                IT
# 1         DELHI     ARTS,IT,MGMT,
# ...

# %%
#  by-default it only read the first sheet data but we can read any sheet data by giving name of sheet like
pd.read_excel('D:\Practice data_1.xlsx',sheet_name='Sheet2')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# i m not getting anything boz sheet2 does not contain any data if data is there it will read

# %%
#  now reading a html page data using 
df5=pd.read_html('https://www.basketball-reference.com/teams/MIA/2022.html')

# %%
df5
# Out:
# [    No.              Player Pos   Ht   Wt          Birth Date Unnamed: 6 Exp  \
#  0    55     Duncan Robinson  SG  6-7  215      April 22, 1994         us   3
#  1    17         P.J. Tucker  PF  6-5  245         May 5, 1985         us  10
#  2    31           Max Strus  SF  6-5  215      March 28, 1996         us   2
#  3     2        Gabe Vincent  PG  6-3  200       June 14, 1996         us   2
#  4    21      Dewayne Dedmon   C  7-0  245     August 12, 1989         us   8
#  5    14         Tyler Herro  SG  6-5  195    January 20, 2000         us   2
#  6     7          Kyle Lowry  PG  6-0  196      March 25, 1986         us  15
#  7    16        Caleb Martin  SF  6-5  205  September 28, 1995         us   2
#  8    22        Jimmy Butler  SF  6-7  230  September 14, 1989         us  10
#  9    13         Bam Adebayo   C  6-9  255       July 18, 1997         us   4
#  10   77      Omer Yurtseven   C  7-0  264       June 19, 1998         tr   R
# ...

# %%
type(df5)  # boz i just passed the link of site so what ever no of tables that html page contains all will be shown inside a list as above
# Out:
# list

# %%
len(df5)  # for getting how many tables are there
# Out:
# 7

# %%
#  data of any particular table by just giving table index as an argument 
df5[0]
# Out:
#     No.              Player Pos   Ht   Wt          Birth Date Unnamed: 6 Exp  \
# 0    55     Duncan Robinson  SG  6-7  215      April 22, 1994         us   3
# 1    17         P.J. Tucker  PF  6-5  245         May 5, 1985         us  10
# 2    31           Max Strus  SF  6-5  215      March 28, 1996         us   2
# 3     2        Gabe Vincent  PG  6-3  200       June 14, 1996         us   2
# 4    21      Dewayne Dedmon   C  7-0  245     August 12, 1989         us   8
# 5    14         Tyler Herro  SG  6-5  195    January 20, 2000         us   2
# 6     7          Kyle Lowry  PG  6-0  196      March 25, 1986         us  15
# 7    16        Caleb Martin  SF  6-5  205  September 28, 1995         us   2
# 8    22        Jimmy Butler  SF  6-7  230  September 14, 1989         us  10
# 9    13         Bam Adebayo   C  6-9  255       July 18, 1997         us   4
# 10   77      Omer Yurtseven   C  7-0  264       June 19, 1998         tr   R
# ...

# %%
df5[3]
# Out:
#       Rk         Unnamed: 1   Age   G    GS     MP    FG   FGA    FG%    3P  \
# 0    1.0        Tyler Herro  22.0  66  10.0   2151   501  1122  0.447   175
# 1    2.0         Kyle Lowry  35.0  63  63.0   2133   276   627  0.440   144
# 2    3.0    Duncan Robinson  27.0  79  68.0   2043   290   726  0.399   232
# 3    4.0        P.J. Tucker  36.0  71  70.0   1981   207   428  0.484    80
# 4    5.0       Jimmy Butler  32.0  57  57.0   1931   398   829  0.480    27
# 5    6.0        Bam Adebayo  24.0  56  56.0   1825   406   729  0.557     0
# 6    7.0       Gabe Vincent  25.0  68  27.0   1589   214   513  0.417   119
# 7    8.0          Max Strus  25.0  68  16.0   1587   249   564  0.441   181
# 8    9.0       Caleb Martin  26.0  60  12.0   1372   208   410  0.507    64
# 9   10.0     Dewayne Dedmon  32.0  67  15.0   1065   164   290  0.566    19
# 10  11.0     Omer Yurtseven  23.0  56  12.0    706   130   247  0.526     1
# ...

# %%
#  i can store these tables in csv format like
df5[0].to_csv('players_details.csv')

# %%
pd.read_csv('https://gist.githubusercontent.com/jwalsh/ce1dc0436aba5b7a5c9666f47fa5a380/raw/5ce3854392b43ff97907112d344fc008229b0445/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass         Lname  \
# 0              1         0       3        Braund
# 1              2         1       1       Cumings
# 2              3         1       3     Heikkinen
# 3              4         1       1      Futrelle
# 4              5         0       3         Allen
# ..           ...       ...     ...           ...
# 151          152         1       1         Pears
# 152          153         0       3           Meo
# 153          154         0       3  van Billiard
# 154          155         0       3         Olsen
# 155          156         0       1      Williams
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 0                                Mr. Owen Harris    male  22.0      1      0
# 1     Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                    Miss. Laina  female  26.0      0      0
# ...

# %%
# working with json data files is not completed ,complete it if it is need for any python project or ML projects if not than complete it after ML projects completion or at the end of this course  
import json

# %%
json.loads(s)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Input In [111], in <cell line: 1>()
# ----> 1 json.loads(s)
#
# File D:\downloads\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File D:\downloads\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
# ...

# %%
# data which is in json format is actually in key and value format inside a dictionary 
# for converting json data into a dataframe  type using pandas like
pd.DataFrame('D:\product_tree.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [115], in <cell line: 3>()
#       1 # data which is in json format is actually in key and value format inside a dictionary
#       2 # for converting json data into a dataframe  type using pandas like
# ----> 3 pd.DataFrame('D:\product_tree.json')
#
# File D:\downloads\lib\site-packages\pandas\core\frame.py:756, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     753 # For data is scalar
#     754 else:
#     755     if index is None or columns is None:
# --> 756         raise ValueError("DataFrame constructor not properly called!")
#     758     # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#     759     # expected "Union[Union[Union[ExtensionArray, ndarray],
#     760     # Index, Series], Sequence[Any]]"
#     761     index = ensure_index(index)  # type: ignore[arg-type]
#
# ...
