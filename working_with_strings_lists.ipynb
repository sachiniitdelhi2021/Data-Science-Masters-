# %%
a= 'my name is sachin'

# %%
a
# Out:
# 'my name is sachin'

# %%
# various operations with strings

# %%
a.find('m')   # finding any characters index   # if more than 1 same characters are available inside main string then find function gives 
              #   index of first character or lowest index
# Out:
# 0

# %%
a.find('mn')  # whenever we find any sub-string but if it is not available inside main string then find function will give us -1
# Out:
# -1

# %%
a.find('name')
# Out:
# 3

# %%
a.find('my')
# Out:
# 0

# %%
for i in range(len('name')):      # finding index of sub-string inside main string 
  print(i+3)
# Out:
# 3
# 4
# 5
# 6

# %%
a.count('m')   # gives how many times 'm' is appeared in string
# Out:
# 2

# %%
a.count('a')      # gives how many times 'a' is appeared in string
# Out:
# 2

# %%
a.index('m')
# Out:
# 0

# %%
a.split()
# Out:
# ['my', 'name', 'is', 'sachin']

# %%
b='my name is, sachin'
b.split(',')      # spliting by ,(commas)
# Out:
# ['my name is', ' sachin']

# %%
b.split('m')  # spliting the main string from where characters ''m'' comes
# Out:
# ['', 'y na', 'e is, sachin']

# %%
type(b.split(','))
# Out:
# list

# %%
b.upper()       # converts all lower case characters into upper case of main string
# Out:
# 'MY NAME IS, SACHIN'

# %%
c=b.upper()
c
# Out:
# 'MY NAME IS, SACHIN'

# %%
c.lower()           # converts all upper case characters into lower case of main string
# Out:
# 'my name is, sachin'

# %%
d= 'MY name IS SACHIN'

# %%
d.swapcase()     # converts lower case to upper case and vice-versa
# Out:
# 'my NAME is sachin'

# %%
' '.join(d)           # joins space after every character of string
# Out:
# 'M Y   n a m e   I S   S A C H I N'

# %%
'1'.join(d)               # joins 1 after every character of string stored in variable ''d''
# Out:
# 'M1Y1 1n1a1m1e1 1I1S1 1S1A1C1H1I1N'

# %%
d[::-1]    # reversing the complete string
# Out:
# 'NIHCAS SI eman YM'

# %%
for i in reversed(d):    # for reversing the complete string 
  print(i)
# Out:
# N
# I
# H
# C
# A
# S
#
# S
# I
#
# e
# m
# a
# n
#
# Y
# M

# %%
d= '   sachin   '    # removes the space before and after the string 
d.strip()
# Out:
# 'sachin'

# %%
d.lstrip()    # removes the left side space of string
# Out:
# 'sachin   '

# %%
d.rstrip()    # removes the right side space of string
# Out:
# '   sachin'

# %%
d='sachin dangi'

# %%
d.replace('dangi','thakur')    # with replace func... we can replace any character or word of string with other
# Out:
# 'sachin thakur'

# %%
d.replace('s','d')
# Out:
# 'dachin dangi'

# %%
d      # when we perform replace operation in string the new string gets stored inside memory occupying new space
# Out:
# 'sachin dangi'

# %%
d= d.replace('dangi','thakur')

# %%
d
# Out:
# 'sachin thakur'

# %%
d.center(20,'*')    # center function, 20 positions will be created and string inside 'd' will occupy center positions
# Out:
# '***sachin thakur****'

# %%
a='sachin\tsingh\tdangi'      # \t is for tab and if we use expandtabs function space will create wherever tab is there in string   
a.expandtabs()
# Out:
# 'sachin  singh   dangi'

# %%
a=' we all are a part of Full stack '
#  converting string into lower case
a.lower()
# Out:
# ' we all are a part of full stack '

# %%
#  no. of times ''a'' occured in string
a.count('a')
# Out:
# 5

# %%
len(a)
# Out:
# 31

# %%
#  locations of all 'a' in string   
for i in range(0,31):
  if a[i]=='a':
   print(i)
# Out:
# 3
# 7
# 11
# 14
# 28

# %%
#  replacing all ''a'' with ineuron
a.replace('a','ineuron')
# Out:
# 'we ineuronll ineuronre ineuron pineuronrt of Full stineuronck'

# %%
#  printing all words of string as list
a.split()
# Out:
# ['we', 'all', 'are', 'a', 'part', 'of', 'Full', 'stack']

# %%
#  checking inbuilt functions/operations for string which starts with 'is' and always return 'true' or 'false'

# %%
#  checking string is having all uppercase characters
a.isupper()
# Out:
# False

# %%
#  checking string is having all lowercase characters
a.islower()
# Out:
# False

# %%
a
# Out:
# ' we all are a part of Full stack '

# %%
#  checking for space before and after the string
a.isspace()
# Out:
# False

# %%
# checking for digits only in string
a.isdigit()
# Out:
# False

# %%
# checking is string ending with ''k'''
a.endswith(' ')
# Out:
# True

# %%
# checking string starts with space
a.startswith(' ')
# Out:
# True

# %%
a='Sachin'

# %%
# checking string is alphanumeric or not (containing both alphabets and numbers or either of two )
a.isalnum()     # there should be no space b/w characters and numbers
# Out:
# True

# %%
a.isalpha()   # checks for aplhabets only
# Out:
# True

# %%
#  checking for title if first character is uppercase 
a.istitle()
# Out:
# True

# %%
# some other operations

# %%
# how to print size of string without using function len()
count=0
for i in a:
  count = count+1
  print(count)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
#  without using a[::-1] for reversing the string
for i in range(1,len(a)):
  print(a[-i])
# Out:
# n
# i
# h
# c
# a

# %%
#  also we can reverse string in this way aslo using while loop
a='sachin'
c=len(a)-1
while c>=0:
  print(a[c])
  c=c-1
# Out:
# n
# i
# h
# c
# a
# s

# %%
name ='sachin'
vowels='AaEeIiOoUu'
for i in name:
  if i in vowels:
    print('{} is a vowel'.format(i))   # format function adds i value every time in space created by {}
  else:
    print('{} is not a vowel'.format(i))
# Out:
# s is not a vowel
# a is a vowel
# c is not a vowel
# h is not a vowel
# i is a vowel
# n is not a vowel

# %%
#  what format function do 
name=input()
surname=input()
print('my name is {} {}'.format(name,surname) )
# Out:
# sachin
# dangi
# my name is sachin dangi

# %%
#  checking for pelindrom (a datatype which may be string,integer etc ) is same in forward and backward direction is pelindrom

a=input('enter something which u want to check is pelindrom or not')
if a[::1]==a[::-1]:
  print('yes it is pelindrom')
else:
  print('is is not a ''pelindrom')
# Out:
# enter something which u want to check is pelindrom or notnitin
# yes it is pelindrom

# %%
#  list manupilations

# %%
l=['sachin',123, 321,[888,000,999],987]
l[0]  # this will give item inside list 'l' at index 0
l[3]
# Out:
# [888, 0, 999]

# %%
l[0:4]  # will give items of list ''l'' in range from index 0 till 3
# Out:
# ['sachin', 123, 321, [888, 0, 999]]

# %%
l[::1]   # will give complete list in forward direction
# Out:
# ['sachin', 123, 321, [888, 0, 999], 987]

# %%
l[::-1]  # will give complete list items in backward direction
# Out:
# [987, [888, 0, 999], 321, 123, 'sachin']

# %%
a='sachin'
l+a    #  we cannot concatenate string with list, therefore have to change string to list using type casting
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-220-612bdbc0e282> in <module>()
#       1 a='sachin'
# ----> 2 l+a    #  we cannot concatenate string with list so have to change string to list using type casting
#
# TypeError: can only concatenate list (not "str") to list

# %%
b=list(a)   # converting string inside ''a'' into list using type casting
l+b
# Out:
# ['sachin', 123, 321, [888, 0, 999], 987, 's', 'a', 'c', 'h', 'i', 'n']

# %%
l
# Out:
# ['sachin', 123, 321, [888, 0, 999], 987]

# %%
l*2    # will give complete list two times
# Out:
# ['sachin',
#  123,
#  321,
#  [888, 0, 999],
#  987,
#  'sachin',
#  123,
#  321,
#  [888, 0, 999],
#  987]

# %%
len(l)    # finding no. of items inside list using function 'len()'
# Out:
# 5

# %%
# checking sachin item is there in list 'l' or not
'sachin'in l
# Out:
# True

# %%
123 in l
# Out:
# True
