# %%
# tuple and it's properties and how it is different from list

# %%
t=()    # empty tuple
type(t)
# Out:
# tuple

# %%
t=('sachin','dangi',123,345)
#  calling any item of tuple 
t[0]   # same as whhat we did in case of list
# Out:
# 'sachin'

# %%
# calling complete tuple same as what we do in case of list
t[::1]
# Out:
# ('sachin', 'dangi', 123, 345)

# %%
l=[]  # empty list
type(l)
# Out:
# list

# %%
l=['sachin','dangi',123,345]
l[0]
# Out:
# 'sachin'

# %%
l[::1]  # calling complete list
# Out:
# ['sachin', 'dangi', 123, 345]

# %%
# first diff.. b/w list and typle is that list is mutable but tulpe is immutable 
# one's items of tuple are assigned cannot be changed means tuple does not support item assignment

# %%
l[1]='thakur'

# %%
l
# Out:
# ['sachin', 'thakur', 123, 345]

# %%
t[1]='thakur'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-d6b415392c5a> in <module>()
# ----> 1 t[1]='thakur'
#
# TypeError: 'tuple' object does not support item assignment

# %%
t2=(1,2,3)   # append operation can be performed for tuples too like list 
t+t2
# Out:
# ('sachin', 'dangi', 123, 345, 1, 2, 3)

# %%
t2*2    # if we want to add same items of tuple multiple times then we can use this same as list
# Out:
# (1, 2, 3, 1, 2, 3)

# %%
# checking any item exist in tuple or not 
'sachin' in t   # yes it exist
# Out:
# True

# %%
#  if tuple contains only integers we can find maxi.. and mini... integer vaue like
t=(1,2,3,4)
#  for maximum integer value 
max(t)
# Out:
# 4

# %%
#  for minimum value 
min(t)
# Out:
# 1

# %%
# max and min function does not work if tuple contains mix of datatypes like string,integer,boolean etc 
t=('hggf',123)
max(t)    # will not work
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-0664192ca87c> in <module>()
#       1 # max and min function does not work if tuple contains mix of datatypes like string,integer,boolean etc
#       2 t=('hggf',123)
# ----> 3 max(t)
#
# TypeError: '>' not supported between instances of 'int' and 'str'

# %%
min(t)    # will not work
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-a3c355d35054> in <module>()
# ----> 1 min(t)
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
#  functions in tuples

# %%
#  count function will give count of item inside tuple like list 
t=(1,21,1,1,3,4)
t.count(1)
# Out:
# 3

# %%
#  index function of tuple 
#  it will give index of asked item inside tuple like list
t.index(21)
# Out:
# 1

# %%
# append and insert like functions are not available for tuples boz tuples are immutable

# %%
# if we want to add new item inside tuple without creating new tuple and then adding two
#  i can convert tuple into list and then i m allowed to use append,insert and extend operations and again converting back list to tuple

# %%
t
# Out:
# (1, 21, 1, 1, 3, 4)

# %%
l=list(t)   # converting tuple into list

# %%
l
# Out:
# [1, 21, 1, 1, 3, 4]

# %%
#  now using insert function can insert 'sachin' at any position 
l.insert(0,'sachin')
l
# Out:
# ['sachin', 1, 21, 1, 1, 3, 4]

# %%
# converting back list into tuple 
t=tuple(l)
t
# Out:
# ('sachin', 1, 21, 1, 1, 3, 4)

# %%
# tuples only have 2 functions 'count' and 'index'

# %%
'''suppose i want to store some data which i don't want any other person to change except me
  i can use tuples for this like my gmail password, so i will create a variable in form of tuple 
  to store my password '''

# %%
#  tuples inside tuples called nested tuples even we can store list inside tuple like

t=((1,2,3),('sachin','dangi'),[1,2,3,'thakur'],1223,344)
#  calling any tuple inside tuple like
t[0]
# Out:
# (1, 2, 3)

# %%
# can call any item of nested tuples like
t[0][1]
# Out:
# 2

# %%
# calling list inside tuple
t[2]
# Out:
# [1, 2, 3, 'thakur']

# %%
# calling any item of list inside tuple
t[2][3]
# Out:
# 'thakur'

# %%
t[2][1:3]   # if i want 2 and 3 then i can do
# Out:
# [2, 3]

# %%
# printing first item of every tuple in nested tuple using
for i in t:
  if type(i)==tuple:
    print(i[0])
# Out:
# 1
# sachin

# %%
t
# Out:
# ((1, 2, 3), ('sachin', 'dangi'), [1, 2, 3, 'thakur'], 1223, 344)

# %%
t1=((1, 2, 3), [1, 2, 3, 'thakur'],('sachin', 'dangi'), 1223)

# %%
t1
# Out:
# ((1, 2, 3), [1, 2, 3, 'thakur'], ('sachin', 'dangi'), 1223)

# %%
#  checking length of 2 tuples is same or not
if len(t)==len(t1):
  print('same length as',len(t))
else:
  print('lengths are not same')
# Out:
# lengths are not same

# %%
# if two tuples have same length then checking and printing same items inside tuples
for i in range(len(t)):
  if t[i]==t1[i]:    #this will only give same elements if they are at same index position 
    print(t[i])       # if same elements exists at diff.. index positions then this will not work properly   
                      #  will not  work if tuples have differnet lenghts

# %%
# if same item inside two tuples but at different index positions the we can use nested for loops for getting those items 

for i in range(len(t)):
  for j in range(len(t1)):    # will work even if two tuples are not having same legths
    if t1[j]==t[i]:
      print(t[i])
# Out:
# (1, 2, 3)
# ('sachin', 'dangi')
# [1, 2, 3, 'thakur']
# 1223

# %%
# taking input from user and then compairing it with items of existing tuple and printing some kind of message 
t=('sachin','dangi','9752050888','iit delhi')
a=input('name is :')
b=input(('surname is :'))
c=input('mobile no is:')
d=input('college is:')

l=[]
l.insert(0,a)
l.insert(1,b)
l.insert(2,c)
l.insert(3,d)

t1=tuple(l)

for i in range(len(t)):
  if t1[i]==t[i]:
    print('what u typed is correct')
  else:
    print('what u typed is wrong')
# Out:
# name is :sachin
# surname is :dangi
# mobile no is:9752050888
# college is:iit delhi
# what u typed is correct
# what u typed is correct
# what u typed is correct
# what u typed is correct

# %%
#  another way in which i can take input from user and compare it with items of  tuple and give response accordingly

t
# Out:
# ('sachin', 'dangi', '9752050888', 'iit delhi')

# %%
i=input('type something: ')

if i in t:
  print('{} exists inside tuple t:'.format(i))
else:
  print('{} not exists inside tuple t:'.format(i))
# Out:
# type something: sachin
# sachin exists inside tuple t:

# %%
#  we can delete any tuple and list using function 'del()'
l=['jhgv',12,3334,344]

# %%
l
# Out:
# ['jhgv', 12, 3334, 344]

# %%
del(l)

# %%
l    # now list l does not exists now
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-cde25b5e10ad> in <module>()
# ----> 1 l
#
# NameError: name 'l' is not defined

# %%
#  ''set'' is another collection present inside core python like list and tuple which can store things
l=[1,1,1,2,2,3,3,3,4,4,'sachin','sachin']
# suppose we want data which does not contains same thing more than one only unique item 
# here comes 'set' with the help of which  we can do this
set(l)
# Out:
# {1, 2, 3, 4, 'sachin'}

# %%
#  set is a collection of unique data 
l=[1,1,1,2,2,3,3,3,4,4,'Sachin','sachin']

# %%
set(l)    # set is case sensitive it will treate Sachin and sachin differently
# Out:
# {1, 2, 3, 4, 'Sachin', 'sachin'}

# %%
s=set(l)

# %%
s
# Out:
# {1, 2, 3, 4, 'Sachin', 'sachin'}

# %%
for i in s:
  print(i)
# Out:
# 1
# 2
# 3
# 4
# Sachin
# sachin

# %%
#  checking item exists in set or not 
4 in s
# Out:
# True

# %%
#  NOTE---  set does not give ordered data it is an illusion

# %%
#  default functions available for ''set'' 
s
# Out:
# {1, 2, 3, 4, 'Sachin', 'sachin'}

# %%
#  ''add'''function
t=set()
t.add(45)
t.add(34)
t.add(62)         # when we add integers in set ,it arranges all in order like this

# %%
t
# Out:
# {34, 45, 62}

# %%
# we cannot add list inside set unlike tuple 
t.add([1,2,3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-110-9b274971c7fd> in <module>()
#       1 # we cannot add list inside set unlike tuple
# ----> 2 t.add([1,2,3])
#
# TypeError: unhashable type: 'list'

# %%
#  can remove any item of set using remove function
s
# Out:
# {1, 2, 3, 4, 'Sachin', 'sachin'}

# %%
s.remove('sachin')
s
# Out:
# {1, 2, 3, 4, 'Sachin'}

# %%
#  clear function clears all items of set like 
s.clear()
s
# Out:
# set()

# %%
s1= {'sachin','dangi',123,334,445}

# %%
s1
# Out:
# {123, 334, 445, 'dangi', 'sachin'}

# %%
s2={'singh','thakur',888,000,999}
s2
# Out:
# {0, 888, 999, 'singh', 'thakur'}

# %%
'''set does not support two or more set addition or append operation boz if any item in any two or more set is same then resulting set 
will not have all unique elements '''

s1+s2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-125-7f1c4d7e5c0f> in <module>()
#       2 will not have all unique elements '''
#       3
# ----> 4 s1+s2
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
# set also not support number multiplication operation unlike list and tuples 
s1*2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-126-33d91482b03d> in <module>()
#       1 # set also not support number multiplication operation unlike list and tuples
# ----> 2 s1*2
#
# TypeError: unsupported operand type(s) for *: 'set' and 'int'

# %%
# we can convert set,list and tuples from each other to remaining two 
l=list(s1)
l
# Out:
# ['dangi', 334, 123, 445, 'sachin']

# %%
t=tuple(s1)
t
# Out:
# ('dangi', 334, 123, 445, 'sachin')

# %%
set(t)
# Out:
# {123, 334, 445, 'dangi', 'sachin'}

# %%
# NOTE-- in set items are not assigned any index so we cannot use function like s[0] to get item at that index value

# %%
# ''Dictionary''---

# %%
x1={12,'sachin',9987}   
type(x1)
# Out:
# set

# %%
x={'name':'sachin','surname':'thakur','age':24, True:1,False:0}
type(x)
# Out:
# dict

# %%
'''NOTE-- both set and dictionary stores data inside curly braces but in set the data is flatten simply integers,strings,float,boolen
but in case of dictionary we have ''key'' and it's value pairs '''

# %%
# NOTE-- in case of dictionary key should always be unique whereas value can be same and also special case characters % # @ & cannot be key 
   #  also we can store list ,tuple,set,dictionary as value of some key inside dictionary like
#  we cannot make list and set as key but we can make tuple as key

# %%
d={'name':'sachin','surname':'thakur','age':{32,23,9}, True:('xx',22212,878,987),False:[1,2,3,4,'sachin']}

# %%
d
# Out:
# {False: [1, 2, 3, 4, 'sachin'],
#  True: ('xx', 22212, 878, 987),
#  'age': {9, 23, 32},
#  'name': 'sachin',
#  'surname': 'thakur'}

# %%
# we can get value of any key by providing key as argument like
d['name']
# Out:
# 'sachin'

# %%
d[False][4]   # getting item at index 4 in list which is a value for key False
# Out:
# 'sachin'

# %%
d[True][0]
# Out:
# 'xx'

# %%
d1={'name':'sachin','surname':'thakur','age':{12,276,0}, True:('xx',202212,9878,2987),False:[12,2,23,42,'sachin']}

# %%
#  append operation for dictionary 
d+d1     # same as set does not work
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-ed510c2cfed5> in <module>()
#       1 #  append operation for dictionary
# ----> 2 d+d1     # same as set does not work
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
#  multiplication operation also not work like set 
d*2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-ebe7fb4166f3> in <module>()
#       1 #  multiplication operation also not work like set
# ----> 2 d*2
#
# TypeError: unsupported operand type(s) for *: 'dict' and 'int'

# %%
# but we can replace any key value with new value like list and set 
d['surname']='dangi'

# %%
d
# Out:
# {False: [1, 2, 3, 4, 'sachin'],
#  True: ('xx', 22212, 878, 987),
#  'age': {9, 23, 32},
#  'name': 'sachin',
#  'surname': 'dangi'}

# %%
#  Dictionary is a mutuable entity like list and set but unlike tuples

# %%
d['surname']=123
d
# Out:
# {False: [1, 2, 3, 4, 'sachin'],
#  True: ('xx', 22212, 878, 987),
#  'age': {9, 23, 32},
#  'name': 'sachin',
#  'surname': 123}

# %%
d['surname']-= 23   # can subtract any number from existing number stored as value of any key
d
# Out:
# {False: [1, 2, 3, 4, 'sachin'],
#  True: ('xx', 22212, 878, 987),
#  'age': {9, 23, 32},
#  'name': 'sachin',
#  'surname': 28}

# %%
d['surname']+= 10 
d
# Out:
# {False: [1, 2, 3, 4, 'sachin'],
#  True: ('xx', 22212, 878, 987),
#  'age': {9, 23, 32},
#  'name': 'sachin',
#  'surname': 48}

# %%
d.keys()      # can print all keys of this dictionary ''d''
# Out:
# dict_keys(['name', 'surname', 'age', True, False])

# %%
#  can check any particular key exists inside dictionary or not 
'name' in d.keys()
# Out:
# True

# %%
# printing values of all keys 
for i in d.keys():
  print(d[i])
# Out:
# sachin
# 103
# {32, 9, 23}
# ('xx', 22212, 878, 987)
# [1, 2, 3, 4, 'sachin']

# %%
#  also i can datatype of each values like 
for i in d.keys():
  print(type(d[i]))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'set'>
# <class 'tuple'>
# <class 'list'>

# %%
d.items()  # this will give key and value pairs in tuples form
# Out:
# dict_items([('name', 'sachin'), ('surname', 103), ('age', {32, 9, 23}), (True, ('xx', 22212, 878, 987)), (False, [1, 2, 3, 4, 'sachin'])])

# %%
len(d.items())
# Out:
# 5

# %%
#  getting keys only out of above data set 
for i in d.items():
  print(i[0])
# Out:
# name
# surname
# age
# True
# False

# %%
#  practise questions

# %%
# (Q1)--- taking paragraph as input from user and converting it into list then remove all duplicate items from list 

a= input('enter a paragraph:')
# Out:
# enter a paragraph:sachin is a good boy sachin lives in delhi  sachin studies in iit delhi  sachin loves horses and lions

# %%
b= a.split()   # converting string into a list using ''split'''function 
b
# Out:
# ['sachin',
#  'is',
#  'a',
#  'good',
#  'boy',
#  'sachin',
#  'lives',
#  'in',
#  'delhi',
#  'sachin',
#  'studies',
#  'in',
#  'iit',
#  'delhi',
#  'sachin',
#  'loves',
#  'horses',
#  'and',
#  'lions']

# %%
c=set(b)   # removing all duplicate items from list by converting it into set 
c
# Out:
# {'a',
#  'and',
#  'boy',
#  'delhi',
#  'good',
#  'horses',
#  'iit',
#  'in',
#  'is',
#  'lions',
#  'lives',
#  'loves',
#  'sachin',
#  'studies'}

# %%
d={}        # empty  dictionary
for i in c:             # taking items of set c as key and givind them values 'sachin' and creating a dictionary  
  d[i]='sachin'
d
# Out:
# {'a': 'sachin',
#  'and': 'sachin',
#  'boy': 'sachin',
#  'delhi': 'sachin',
#  'good': 'sachin',
#  'horses': 'sachin',
#  'iit': 'sachin',
#  'in': 'sachin',
#  'is': 'sachin',
#  'lions': 'sachin',
#  'lives': 'sachin',
#  'loves': 'sachin',
#  'sachin': 'sachin',
#  'studies': 'sachin'}

# %%
#  we can also use inbuilt function ''dict.fromkeys(c,'sachin')  one-by on every element of set c will be assigned same value and a dictionary  will be created 
d=dict.fromkeys(c,'sachin')
d
# Out:
# {'a': 'sachin',
#  'and': 'sachin',
#  'boy': 'sachin',
#  'delhi': 'sachin',
#  'good': 'sachin',
#  'horses': 'sachin',
#  'iit': 'sachin',
#  'in': 'sachin',
#  'is': 'sachin',
#  'lions': 'sachin',
#  'lives': 'sachin',
#  'loves': 'sachin',
#  'sachin': 'sachin',
#  'studies': 'sachin'}

# %%
type(d)  # type of d
# Out:
# dict

# %%
#  printing all key values inside a tuple
l=[]   # empty list 
for i in d.keys():
  l.append(d[i])
l
#  converting list into tuple 
t=tuple(l) 
t
# Out:
# ('sachin',
#  'sachin',
#  'sachin',
#  'sachin',
#  'sachin',
#  'sachin',
#  'sachin',
#  'sachin',
#  'sachin',
#  'sachin',
#  'sachin',
#  'sachin',
#  'sachin',
#  'sachin')

# %%
#  directly printing all values of dictionary inside tuple using
t1=tuple(d.values())
t1
# Out:
# ('sachin',
#  'sachin',
#  'sachin',
#  'sachin',
#  'sachin',
#  'sachin',
#  'sachin',
#  'sachin',
#  'sachin',
#  'sachin',
#  'sachin',
#  'sachin',
#  'sachin',
#  'sachin')

# %%
#  printing all keys in inside list
l1=[]  # first create empty list  
for i in d.keys():
  l1.append(i)
print(l1)
# Out:
# ['lives', 'lions', 'studies', 'in', 'and', 'boy', 'sachin', 'horses', 'loves', 'a', 'is', 'good', 'iit', 'delhi']

# %%
#  printing all keys of ''d'' inside list using single line code 
l1=list(d.keys())
l1
# Out:
# ['lives',
#  'lions',
#  'studies',
#  'in',
#  'and',
#  'boy',
#  'sachin',
#  'horses',
#  'loves',
#  'a',
#  'is',
#  'good',
#  'iit',
#  'delhi']

# %%
#  itterations in dictionary

# %%
d={'name':'sachin','surname':'thakur','age':24}
#  checking age is > than 24 or not if not than updating it 
for i in d:
  if i=='age':
    if d[i]>24:
      print('age is greater than 24')
    else:
      d[i]=25

# %%
d
# Out:
# {'age': 25, 'name': 'sachin', 'surname': 'thakur'}

# %%
for i in d:
  print('key is:',i,',','value is:',d[i])
# Out:
# key is: name , value is: sachin
# key is: surname , value is: thakur
# key is: age , value is: 25

# %%
# dictionary comprehensations

# %%
# creating dictionary with key as numbers from 0 to 9 and corresponding values are it's square
d={}
for i in range(11):
  d[i]=i*i
print(d)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %%
#  above same operation just in one line code 
{i:i*i for i in range(11)}
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}
