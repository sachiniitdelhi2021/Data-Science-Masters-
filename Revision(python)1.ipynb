# %%
a=10
type(a)
# Out:
# int

# %%
b='sachin'
type(b)
# Out:
# str

# %%
a
# Out:
# 10

# %%
b
# Out:
# 'sachin'

# %%
a,b,c,d=10,20,'sachin','dangi'

# %%
a
# Out:
# 10

# %%
b
# Out:
# 20

# %%
c
# Out:
# 'sachin'

# %%
d
# Out:
# 'dangi'

# %%
a=True
b=False

# %%
type(a)
# Out:
# bool

# %%
a
# Out:
# True

# %%
b
# Out:
# False

# %%
type(b)
# Out:
# bool

# %%
# complex no. writing
a=20+20j

# %%
a
# Out:
# (20+20j)

# %%
# for real part of complex no. do this
a.real
# Out:
# 20.0

# %%
a.imag
# Out:
# 20.0

# %%
a.conjugate
# Out:
# <function complex.conjugate>

# %%
# type casting 
a=10
b=str(a)

# %%
b
# Out:
# '10'

# %%
c='10'

# %%
# we can do string-string concatenation like

# %%
b+c
# Out:
# '1010'

# %%
# converting string into integer using type casting 
int(b+c)
# Out:
# 1010

# %%
type(int(b+c))
# Out:
# int

# %%
a=input()
# Out:
# 10

# %%
a
# Out:
# '10'

# %%
type(a)
# Out:
# str

# %%
b=int(input())
# Out:
# 20

# %%
b
# Out:
# 20

# %%
type(b)
# Out:
# int

# %%
# if, elif, else conditions
#  elif-- is used for writing multiple conditions like

# %%
a=int(input())
if a<12:
  print('input no. is less than 12')
elif a<100:
  print('no. is less than 100')
else:
  print('no.is greater than 100')
# Out:
# 10
# input no. is less than 12

# %%
a=10
b=20
if a==10 or b==20:
  print('condition is true')
# Out:
# condition is true

# %%
# while loop-- in while loop we give any condition if that is true while loop keep on running the moment condition is false while loop stops 
a=10
b=20
count=0
while a<b:
  print('a is less than b')
  count=count+1
  if count==10:
    break
else:
  print('a is not less than b')
# Out:
# a is less than b
# a is less than b
# a is less than b
# a is less than b
# a is less than b
# a is less than b
# a is less than b
# a is less than b
# a is less than b
# a is less than b

# %%
a='sachin'

# %%
a[0]
# Out:
# 's'

# %%
a[0:4]
# Out:
# 'sach'

# %%
a[0:4:2]
# Out:
# 'sc'

# %%
a[4:0:-1]
# Out:
# 'ihca'

# %%
a[::]
# Out:
# 'sachin'

# %%
a[::-1]
# Out:
# 'nihcas'

# %%
a='my name is sachin'
for j in a:
  if j==i:
    break
    print(j)

# %%
# ṇested foor loop
n=7
for i in range(0,n):
  for j in range(0,i+1):
    print('*',end='')
  print('\r')
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******

# %%
# ṇested foor loop
n=7
for i in range(0,n):
  for j in range(0,7-i):
    
    print('*',end=' ')
    
  print('\r')
# Out:
# * * * * * * *
# * * * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
# ṇested foor loop
n=7
for i in range(0,n):
  for j in range(i):
    print(' ',end='')
  for j in range(0,7-i):
    
    print('*',end='')
    
  print('\r')
# Out:
# *******
#  ******
#   *****
#    ****
#     ***
#      **
#       *

# %%
# ṇested foor loop
n=7
for i in range(0,n):
  for j in range(0,7-i):
    print(' ',end='')
  for j in range(0,i+1):
    
    print('*',end='')
    
  print('\r')
# Out:
#        *
#       **
#      ***
#     ****
#    *****
#   ******
#  *******

# %%
# ṇested foor loop
n=7
for i in range(0,n):
  for j in range(0,6-i):
    print(' ',end='')
  for j in range(0,i+1):
    print('*',end=' ')
  print('\r')
# Out:
#       *
#      * *
#     * * *
#    * * * *
#   * * * * *
#  * * * * * *
# * * * * * * *

# %%
# ṇested foor loop
n=7
for i in range(0,n):
  for j in range(0,i):
    print(' ',end='')
  for j in range(0,7-i):
    print('*',end=' ')
  print('\r')
# Out:
# * * * * * * *
#  * * * * * *
#   * * * * *
#    * * * *
#     * * *
#      * *
#       *

# %%
l=['sachin',36,True,12.98]

# %%
l
# Out:
# ['sachin', 36, True, 12.98]

# %%
l[2]
# Out:
# True

# %%
type(l)
# Out:
# list

# %%
l=list('sachin')

# %%
l
# Out:
# ['s', 'a', 'c', 'h', 'i', 'n']

# %%
#  string is immutable means does not support iteam assignment
a='sachin'

# %%
a[0]=d
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-adac0517c2b3> in <module>()
# ----> 1 a[0]=d
#
# TypeError: 'int' object does not support item assignment

# %%
#  list is mutable object means it support iteam assignment ,it's any iteam can be replaced with any new iteam like
l=['sachin',12,34,45]

# %%
l[0]='dangi'

# %%
l
# Out:
# ['dangi', 12, 34, 45]

# %%
#  using 'find' function for string i can find index of any character of string like
a='sachin'

# %%
a.find('s')
# Out:
# 0

# %%
a.find('g')  # find func.. gives -1 when any sub-string does not exist inside main string
# Out:
# -1

# %%
a.count('i')  # no. of times any character of string is coming
# Out:
# 1

# %%
a.count('h')
# Out:
# 1

# %%
a.split()
# Out:
# ['sachin']

# %%
a='my name is sachin dangi'
a.split()
# Out:
# ['my', 'name', 'is', 'sachin', 'dangi']

# %%
type(a.split())
# Out:
# list

# %%
b='my name is, sachin, thakur, '  # splitting from commas (,) we can also split from any character 
b.split(',')
# Out:
# ['my name is', ' sachin', ' thakur', ' ']

# %%
b.split('a')
# Out:
# ['my n', 'me is, s', 'chin, th', 'kur, ']

# %%
a.upper()
# Out:
# 'MY NAME IS SACHIN DANGI'

# %%
c='SAchin Is mY naMe' 
c.swapcase()
# Out:
# 'saCHIN iS My NAmE'

# %%
# joining func.. of string
'2'.join(c)
# Out:
# 'S2A2c2h2i2n2 2I2s2 2m2Y2 2n2a2M2e'

# %%
a='sachin'

# %%
a[::-1]
# Out:
# 'nihcas'

# %%
for i in reversed(a):
  print(i)
# Out:
# n
# i
# h
# c
# a
# s

# %%
a=' sachin is my name '
a.strip()
# Out:
# 'sachin is my name'

# %%
a.lstrip()
# Out:
# 'sachin is my name '

# %%
a.rstrip()
# Out:
# ' sachin is my name'

# %%
a='sachin dangi'
a.replace('dangi','thakur')
# Out:
# 'sachin thakur'

# %%
a.center(20,'*')
# Out:
# '****sachin dangi****'

# %%
a.index('dangi')
# Out:
# 7

# %%
#  printing all index locations for any particular character in any string
a=' sachin dangi '

# %%
for i in range(len(a)):
  if a[i]=='a':
    print(i)
# Out:
# 2
# 9

# %%
a.isupper()
# Out:
# False

# %%
a.islower()
# Out:
# True

# %%
a.isspace()
# Out:
# False

# %%
a.endswith(' ')
# Out:
# True

# %%
a.startswith(' ')
# Out:
# True

# %%
a='Sachin 36'

# %%
a.isalnum()
# Out:
# False

# %%
a.isalpha()
# Out:
# False

# %%
a.istitle()
# Out:
# True

# %%
# finding length of string without using len() finction
a='sachin'
count=0
for i in a:
  count=count+1
print(count)
# Out:
# 6

# %%
a='sachin'
for i in range(1,len(a)+1):
  print(a[-i])
# Out:
# n
# i
# h
# c
# a
# s

# %%
a='sachin'
i=1
while i<len(a)+1:
  print(a[-i])
  i=i+1
# Out:
# n
# i
# h
# c
# a
# s

# %%
name =input()
print('{} is my name'.format(name))
# Out:
# sachin
# sachin is my name

# %%
a='sachin'
b=0
for i in a:
  b=b+1
print(b)
# Out:
# 6

# %%
# pelindrom -- datatype which is same forward and backward like-- 787, nitin

# %%
s=set()
type(s)
# Out:
# set

# %%
s.add(12)
s.add(32)

# %%
s
# Out:
# {12, 32}

# %%
s.add(12)

# %%
s
# Out:
# {12, 32}

# %%
s.add(32)
s
# Out:
# {12, 32}

# %%
s.add([1,2,3])  # can't add list inside set but can add tuple inside set like
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-11b6def5be14> in <module>()
# ----> 1 s.add([1,2,3])  # can't add list inside set but can add tuple inside set like
#
# TypeError: unhashable type: 'list'

# %%
s.add((1,2,3))

# %%
s
# Out:
# {(1, 2, 3), 12, 32}

# %%
s[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-c9c96910e542> in <module>()
# ----> 1 s[0]
#
# TypeError: 'set' object is not subscriptable

# %%
s.remove(12)

# %%
s
# Out:
# {(1, 2, 3), 32}

# %%
s.clear()

# %%
s
# Out:
# set()

# %%
s={1,2,3}

# %%
type(s)
# Out:
# set

# %%
s[1]=4

# %%
d={'name':'sachin','age':24}

# %%
d.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
d['age']
# Out:
# 24

# %%
for i in d.keys():
  print(d[i])
# Out:
# sachin
# 24

# %%
d.items()
# Out:
# dict_items([('name', 'sachin'), ('age', 24)])

# %%
d.values()
# Out:
# dict_values(['sachin', 24])

# %%
s={1,2,3}

# %%
d=dict.fromkeys(s,'sachin')

# %%
d
# Out:
# {1: 'sachin', 2: 'sachin', 3: 'sachin'}

# %%
t=tuple(d.keys())

# %%
t
# Out:
# (1, 2, 3)

# %%
l=list(d.keys())

# %%
l
# Out:
# [1, 2, 3]

# %%
l1=list(d.values())

# %%
l1
# Out:
# ['sachin', 'sachin', 'sachin']

# %%
d={}
for i in range(11):
  d[i]=i*i
print(d)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %%
{i:i*i for i in range(11)}
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %%
l=list(d.values())

# %%
l
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
t=tuple(l)

# %%
t
# Out:
# (0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100)

# %%
def test(a,b):
  return a+b,a-b,a*b

# %%
v1,v2,v3=test(1,2)

# %%
v1
# Out:
# 3

# %%
v2
# Out:
# -1

# %%
v3
# Out:
# 2

# %%
#  both \n and \r are escape characters 1) \n prints the results in new line 2) \r -content at right of \r replaces content at left of \r and takes the front position

# %%
print('sachin\n is \n my \n name')
# Out:
# sachin
#  is
#  my
#  name

# %%
print('sachin\rdangi')
# Out:
# dangi

# %%
# another way of creating function and that is using keyword 'lambda'
# we can store our function inside any variable also like

# %%
m=lambda a,b: a*b

# %%
m(10,10)
# Out:
# 100

# %%
# docstring--inside it complete info.. about any functions i/p arguments, nature of operation any many more is given

# %%
help(type)

# %%
a='sachin'
next(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-0b7c1ef22dc3> in <module>()
#       1 a='sachin'
# ----> 2 next(a)
#
# TypeError: 'str' object is not an iterator

# %%
a=iter(a)
next(a)
# Out:
# 's'

# %%
next(a)
# Out:
# 'a'

# %%
def test(a):
  for i in range(a):
    yield i**3

# %%
test(3)
# Out:
# <generator object test at 0x7f5ec0604b50>

# %%
for i in test(3):
  print(i)
# Out:
# 0
# 1
# 8

# %%
# another way of creating file 
# %%writefile test1.txt
#  data to add inside file
