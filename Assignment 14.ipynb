# %% [raw]
# 1. What does RGBA stand for?
# 2. From the Pillow module, how do you get the RGBA value of any images?
# 3. What is a box tuple, and how does it work?
# 4. Use your image and load in notebook then, How can you find out the width and height of an Image object?
# 5. What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?
# 6. After making changes to an Image object, how could you save it as an image file?
# 7. What module contains Pillow’s shape-drawing code?
# 8. Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?

# %% [raw]
# 1. What does RGBA stand for?
# Ans- RGBA stands for red,green,blue and alpha, aplha is the fourth channel which is supplemented for three already existing
# channels that are red,green and blue, the alpha specifies the opacity of the color
#
# The RGBA value is a tuple having 4 integer values each value ranging from 0 to 255(both inclusive) and each value corresponds to the amount of each color in any image

# %% [raw]
# 2. From the Pillow module, how do you get the RGBA value of any images?
# Ans-- first we have to import the image funtion from module pillow
#
# !pip install Pillow
# from PIL import Image
# image=Image.open('file_name.png')
# rgba=pick.convert('RGBA')
# values=list(rgba.getdata())

# %%
# !pip install Pillow

# %%
from PIL import Image 
image=Image.open('file_name.png')
rgba=pick.convert('RGBA')
values=list(rgba.getdata())

# %% [raw]
# 3. What is a box tuple, and how does it work?
# Ans-- a box tuple is a tuple with four integers values, x-coordinate, y-coordinate, width and height respectively

# %% [raw]
# 4. Use your image and load in notebook then, How can you find out the width and height of an Image object?
# Ans-
# from PIL import Image
# im=Image.open('15.PNG')
# #  for gettting the width and the height of image
# w,h=im.size
# print('width of image is:',w)
# print('height of image is:',h)

# %% [markdown]
# a=![15.PNG](attachment:15.PNG)

# %%
from PIL import Image 
im=Image.open('file_name','r')
#  for gettting the width and the height of image 
w,h=im.size
print('width of image is:',w)
print('height of image is:',h)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [24], in <cell line: 2>()
#       1 from PIL import Image
# ----> 2 im=Image.open('15.PNG','r')
#       3 #  for gettting the width and the height of image
#       4 w,h=im.size
#
# File ~\anaconda3\lib\site-packages\PIL\Image.py:2953, in open(fp, mode, formats)
#    2950     filename = fp
#    2952 if filename:
# -> 2953     fp = builtins.open(filename, "rb")
#    2954     exclusive_fp = True
#    2956 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '15.PNG'

# %% [raw]
# 5. What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?
# Ans-- using method -- ImageObject.crop((0, 50, 50, 50)) for getting the image exculding the portion having x-coordinate=0
# y-coordinate=50, width=50 and height= 50

# %% [raw]
# 6. After making changes to an Image object, how could you save it as an image file?
# Ans-- after making changes to any image, for saving that file we can use
# from PIL import Image
# image.save('file_name.png')
# # image is just a variable in which we saved the edited image after editing the image

# %% [raw]
# 7. What module contains Pillow’s shape-drawing code?
# Ans-- for drawing anything on the image the module which is required is-- ImageDraw  module

# %% [raw]
# 8. Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?
# Ans-- ImageDraw object has shape drawing methods like point, line or rectangle , for this we have to pass the image object
# to ImageDraw.Draw()  function
