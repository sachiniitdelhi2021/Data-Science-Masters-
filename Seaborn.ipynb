# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
import numpy as np

# %%
#  let's import a dataset called 'tips' from seaborn as 
tips=sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# let's plot a plot for 'tip' vs 'total_bill' using seaborn as 
sns.relplot(x='tip',y='total_bill',data=tips)

# %%
# let's say in any column we have data of type say-- true, false or yes and no type data then we can plot a graph by selecting the smoke column than we will have plot in two different colors
sns.relplot(x='tip',y='total_bill',data=tips,hue='smoker') 
# this 'c' is for color ,any column i select for 'c' based on the no. of groupings of data in that column we will get plot in that differnet colors

# %%
#  as you can see in above plot that we are getting the plot for 'tip' vs 'total_bill' but the colour is divided into 2 based on no. of grouping of data in that column given for 'hue'

# %%
# 
sns.relplot(x='tip',y='total_bill',data=tips,hue='day')

# %%
#  the no. of days in day column based on that the above plot is in that many different colors ,originally ploted for 'tip' vs 'totao_bill'

# %%
# but looking at above plot we can't say on any day out of total peoples how many were smokers and how many were not 
#  we can do this by using another parameter called ---- 'style' as 
sns.relplot(x='tip',y='total_bill',data=tips,hue='day',style='smoker')

# %%
#  now we can see the no. of smokers and non-smokers based on the shape of dot for each of the day

# %%
# say based on tips we want to know which person gave the highest tip so be can set this using diffenet sizes for that as 
sns.relplot(x='tip',y='total_bill',data=tips,size='tip')

# %%
#  you can see the different sizes of dots with which we can easily see which person paid the highest tip

# %%
# creating new dataframe usng pandas and numpy as 
np.random.seed(20)
df=pd.DataFrame(np.random.rand(300,2),columns=['a','b'])

# %%
df
# Out:
#             a         b
# 0    0.588131  0.897714
# 1    0.891531  0.815837
# 2    0.035890  0.691758
# 3    0.378681  0.518511
# 4    0.657951  0.193850
# ..        ...       ...
# 295  0.162785  0.967364
# 296  0.142559  0.726884
# 297  0.719364  0.899507
# 298  0.408745  0.009093
# 299  0.375042  0.291967
#
# [300 rows x 2 columns]

# %%
#  now say i want to plot line graph for data of both the columns 
sns.relplot(x='a',y='b',data=df,kind='line',sort=True)

# %%
# now say i want to load the 'iris' dataset from seaborn 
iris=sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#  plotinf scatter plot for 'sepal_length' & 'sepal_width'
sns.scatterplot(x='sepal_length',y='sepal_width',data=iris)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
# we can also plot garph for catagorical data and any numerical data using---- 'catplot'
sns.catplot(x='day',y='tip',data=tips)

# %%
#  wuth above plot we can see that on saturday and sunday most people visited and also gave the highest tip on saturday

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# now to see who has given more tip smoker or non-smoker 
sns.catplot(x='smoker',y='tip',data=tips)

# %%
# 
sns.catplot(x='day',y='tip',kind='box',data=tips,hue='sex')

# %%
#  more no of outliers are on day saturday in above plot

# %%
x=np.random.randn(1000)

# %%
x
# Out:
# array([ 2.40004265e-01,  3.34608524e-01, -2.03196728e+00, -2.97785440e+00,
#         5.25344648e-02,  1.30917979e+00, -1.12052549e+00,  7.80522400e-01,
#        -2.69218729e+00, -2.20651116e+00,  4.38099192e-02,  9.14514878e-01,
#        -2.05313362e+00, -4.00537030e-01,  5.93976650e-01, -9.96788092e-01,
#         7.29681887e-01,  2.26101439e-01,  5.64170094e-01,  6.58651701e-01,
#         5.05802202e-01,  1.72796739e+00, -7.78886205e-01, -6.10922061e-01,
#         7.52856721e-01,  7.38348029e-01,  2.94971770e-01,  7.01904679e-01,
#        -1.17824753e+00, -5.50526590e-01, -1.89503258e+00,  1.15860012e+00,
#         8.08273888e-01, -4.50259958e-01,  5.34951370e-01,  2.66329847e+00,
#         2.65500439e+00, -1.94310587e+00, -2.49164781e+00,  6.63416903e-01,
#         5.49114979e-01, -8.23416112e-01, -7.85468403e-01,  2.79963747e-01,
#         6.46061357e-01,  4.00830901e-01, -1.02635271e+00,  9.70705991e-01,
# ...

# %%
#  now say if i want to know how much my randomly data in normaly distributed 
#  we can check this with the help of 'distplot()' as 
sns.distplot(x)
# Out:
# D:\downloads\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
# as i increase the size of the data , the data will more likely to follow normal distribution more and more acurately and it will be a standard normal distribution

# %%
y=np.random.randn(100000)
y
# Out:
# array([-0.14738839,  0.03267291, -0.05668489, ...,  0.35534197,
#         0.32269909,  0.32773147])

# %%
sns.distplot(y)
# Out:
# D:\downloads\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
#  the data is very close to be called perfectely noramlly distributed

# %%
# joint plot as
sns.jointplot(x=tips['total_bill'],y=tips['tip'])

# %%
# 
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris)      # same as what we did in case of 'plot' of pandas called 'scatter_matrix' here in seaborn it is called ;pairlpot()

# %%
# lm plot 
sns.lmplot(x='total_bill',y='tip',data=tips)
#  with  the help of this we will get a scatter plot and also a best fitted line without doing a linear regression

# %%
# regression plot
sns.regplot(x='total_bill',y='tip',data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# let's say i want a plot for every day (seperate plot for each day we can get this as )
sns.lmplot(x='total_bill',y='tip',data=tips,col='day')

# %%
#  in above plot you can see the details of total_bill and tip ,seperately for each day with best fit line also
